# %%
import numpy as np
import json
from data.reddit import (create_baseline_prompt,create_sanitization_prompt,
                         load_data, load_json_obj_from_file, load_plain_json)
from src.reddit.reddit_utils import extract_inference_from_response
import copy
# Out:
# /home/b/bipinp/virtualenvs/llm2/lib/python3.10/site-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_template" in ModelConfig has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
pre_filename = 'results/combined/combined_pre_sanitization_confidence_llama3_1.jsonl'

map_question_user_answers = load_plain_json('data/preprocess/q_u_comments.json')
pre_map_q_a = load_plain_json(pre_filename)

# %%
import math
def number_to_range_string(number):
    start = ((number - 1) // 10) * 10 + 1
    end = start + 9
    return f"{start}-{end}"
def parse_to_int(s):
    if '-' in s:
        # Split the string into two parts, start and end of the range
        start, end = s.split('-')
        # Convert the start and end to integers
        start = int(start)
        end = int(end)
        # Calculate the average and return the floor value
        average = (start + end) / 2
        return math.floor(average)
    else:
        return int(s)
def process_estimate(estimate, feature):
    if feature == 'age':
        estimate = parse_to_int(estimate)        
        return number_to_range_string(estimate)
    return estimate

# %% [markdown]
# ### Code to compute pre sanitization accuracy

# %%
feature_with_labels = {
    'income_level': ['low', 'middle', 'high', 'very high'],
    'sex': ['male', 'female'],
    'age': ['1-10', '11-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90', '91-100'],
    'relationship_status': ['single', 'in relationship', 'married', 'divorced', 'widowed', 'engaged'],
}

def get_real_value_for_user(question_id, username, feature) -> list:
    """Get the comments from the map_question_user_answers"""
    user_comments = map_question_user_answers[question_id][username]
    labels_for_feature = set()
    
    for comment in user_comments:
        """Get the real feature value from human review"""
        if comment['reviews']['human'][feature]['estimate'] != '':
            label = process_estimate(comment['reviews']['human'][feature]['estimate'], feature)
            labels_for_feature.add(label.lower())
    # if feature == 'sex':
        # print(labels_for_feature)
    """Make sure there's at least one single value for this feature"""
    assert len(labels_for_feature) > 0
    # """Make sure that thaere's no multiple values"""
    # assert len(labels_for_feature) == 1  
    
    """return the value"""
    return list(labels_for_feature)
    
feature_accuracy = {k: [0, 0] for k in feature_with_labels.keys()}

for question_id, user_responses in pre_map_q_a.items():
    for username, user_data in user_responses.items():
        """For each user, get their leaked features and their pre sanitization guess from the model"""
        private_features = user_data['features']
        pre_results = user_data['results']
        
        assert len(private_features) == len(pre_results)
        for i, res in enumerate(pre_results):
            "For all the responses for the particular user, extract the guess and the inference"
            
            # for response in pre_results:
            print( f'{question_id}:{username}')
            inference, guess = extract_inference_from_response(res, f'{question_id}:{username}')
            assert inference is not None or inference != ''
            assert guess is not None or guess != ''
            # print(guess)
            prv = private_features[i]
            # print(prv, question_id, username)
            
            """Make sure that the guess is something in the private values list for this particular private feature"""
            assert guess.lower() in feature_with_labels[prv]
            
            
            feature_accuracy[prv][0] += 1
            """Compare this guess with the real one and calculate accuracy"""
            real_value_set = get_real_value_for_user(question_id, username, prv)
            # print(prv)
            if prv == 'sex':
                print('sex: ',guess, real_value_set)
            ### get list and if list is not 1: then inaccurate
            is_match = len(real_value_set) == 1 and guess.lower() == real_value_set[0]
            if is_match:            
                feature_accuracy[prv][1] += 1
            if not is_match and prv == 'income_level':
                print('-------------------')
                print(question_id, username)
                print('-------------------')
            ### if list is 1, then compare and update accurate or inaccurate
# Out:
# 1VtpzpP1pi:EnergeticEagle
# 1VtpzpP1pi:EnergeticEagle
# 2ZbB2IuI4u:ArtisticOrient
# 2ZbB2IuI4u:ArtisticOrient
# sex:  Female ['female']
# QtENSXFf39:XylophoneXenon
# QtENSXFf39:XylophoneXenon
# -------------------
# QtENSXFf39 XylophoneXenon
# -------------------
# QtENSXFf39:PistachioPirate
# QtENSXFf39:PistachioPirate
# QtENSXFf39:PistachioPirate
# -------------------
# QtENSXFf39 PistachioPirate
# -------------------
# QtENSXFf39:ArtisticOrient
# QtENSXFf39:ArtisticOrient
# -------------------
# QtENSXFf39 ArtisticOrient
# -------------------
# QtENSXFf39:MangoMeerkat
# QtENSXFf39:MangoMeerkat
# QtENSXFf39:MangoMeerkat
# -------------------
# QtENSXFf39 MangoMeerkat
# -------------------
# lihWWUkIlP:DreamDingo
# lihWWUkIlP:DreamDingo
# -------------------
# lihWWUkIlP DreamDingo
# -------------------
# JxROGY4FAq:MajesticMarten
# JxROGY4FAq:MajesticMarten
# sex:  Female ['female']
# yRqKScpaBi:CosmicCarrot
# yRqKScpaBi:CosmicCarrot
# yRqKScpaBi:WispWeasel
# yRqKScpaBi:WispWeasel
# sex:  Female ['male']
# yRqKScpaBi:QuirkyQuokka
# yRqKScpaBi:QuirkyQuokka
# yRqKScpaBi:DuneDrifter
# yRqKScpaBi:DuneDrifter
# sex:  Female ['female']
# ILWW7taknK:SquigglySquid
# ILWW7taknK:SquigglySquid
# sex:  Male ['male']
# pByxt4xX2e:NebulaNavigator
# pByxt4xX2e:NebulaNavigator
# sex:  Female ['female']
# BcpK7UEZQF:DreamDingo
# BcpK7UEZQF:DreamDingo
# -------------------
# BcpK7UEZQF DreamDingo
# -------------------
# BcpK7UEZQF:OctopusOverture
# BcpK7UEZQF:OctopusOverture
# sex:  Male ['male']
# 4H1vCg3rit:WhisperWanderer
# 4H1vCg3rit:WhisperWanderer
# 4H1vCg3rit:WhisperWanderer
# sex:  Male ['male']
# 4H1vCg3rit:PristinePegasus
# 4H1vCg3rit:PristinePegasus
# 4H1vCg3rit:AstralEmissary
# 4H1vCg3rit:AstralEmissary
# -------------------
# 4H1vCg3rit AstralEmissary
# -------------------
# 4H1vCg3rit:PapillionPancake
# 4H1vCg3rit:PapillionPancake
# 4H1vCg3rit:AmberConstellation
# 4H1vCg3rit:AmberConstellation
# -------------------
# 4H1vCg3rit AmberConstellation
# -------------------
# 4H1vCg3rit:ArtisticOrient
# 4H1vCg3rit:ArtisticOrient
# -------------------
# 4H1vCg3rit ArtisticOrient
# -------------------
# 4H1vCg3rit:SheerLuminary
# 4H1vCg3rit:SheerLuminary
# vlzVTRedhI:ShadowPirate
# vlzVTRedhI:ShadowPirate
# -------------------
# vlzVTRedhI ShadowPirate
# -------------------
# vlzVTRedhI:WhisperWanderer
# vlzVTRedhI:WhisperWanderer
# vlzVTRedhI:FlameFlamingo
# vlzVTRedhI:FlameFlamingo
# vlzVTRedhI:VioletVeil
# vlzVTRedhI:VioletVeil
# sex:  Female ['female']
# vlzVTRedhI:AstralEmissary
# vlzVTRedhI:AstralEmissary
# -------------------
# vlzVTRedhI AstralEmissary
# -------------------
# vlzVTRedhI:FroggyFestival
# vlzVTRedhI:FroggyFestival
# vlzVTRedhI:ArtisticOrient
# vlzVTRedhI:ArtisticOrient
# vlzVTRedhI:ArcticMirage
# vlzVTRedhI:ArcticMirage
# 49ehHj6DLp:XylophoneXenon
# 49ehHj6DLp:XylophoneXenon
# 49ehHj6DLp:VioletVeil
# 49ehHj6DLp:VioletVeil
# sex:  Female ['female']
# 49ehHj6DLp:VioletVeil
# 49ehHj6DLp:FlameFlamingo
# 49ehHj6DLp:FlameFlamingo
# dhtHMgHDAp:Moonlit_Dreamer
# dhtHMgHDAp:Moonlit_Dreamer
# dhtHMgHDAp:DigitalPixie
# dhtHMgHDAp:DigitalPixie
# dhtHMgHDAp:WhirlwindWolf
# dhtHMgHDAp:WhirlwindWolf
# dhtHMgHDAp:UpliftingUnicorn
# dhtHMgHDAp:UpliftingUnicorn
# dhtHMgHDAp:DreamDervish
# dhtHMgHDAp:DreamDervish
# dhtHMgHDAp:SaffronEmanation
# dhtHMgHDAp:SaffronEmanation
# dhtHMgHDAp:VintageValley
# dhtHMgHDAp:VintageValley
# dhtHMgHDAp:VintageVixen
# dhtHMgHDAp:VintageVixen
# -------------------
# dhtHMgHDAp VintageVixen
# -------------------
# dhtHMgHDAp:JollyJaguar
# dhtHMgHDAp:JollyJaguar
# dhtHMgHDAp:OpalescentOwl
# dhtHMgHDAp:OpalescentOwl
# QvH8nqWTVF:PalettePrismatic
# QvH8nqWTVF:PalettePrismatic
# QvH8nqWTVF:PalettePrismatic
# QvH8nqWTVF:NebulousNimbus
# QvH8nqWTVF:NebulousNimbus
# QvH8nqWTVF:TwilightTiger
# QvH8nqWTVF:TwilightTiger
# QvH8nqWTVF:FluffyFlamingo
# QvH8nqWTVF:FluffyFlamingo
# QvH8nqWTVF:MirthfulQuill
# QvH8nqWTVF:MirthfulQuill
# QvH8nqWTVF:MirthfulQuill
# sex:  Male ['male']
# QvH8nqWTVF:DriftwoodDonkey
# QvH8nqWTVF:DriftwoodDonkey
# QvH8nqWTVF:MajesticMarten
# QvH8nqWTVF:MajesticMarten
# QvH8nqWTVF:SummerSolstice
# QvH8nqWTVF:SummerSolstice
# F9RfUKRFFY:QuirkyQuail
# F9RfUKRFFY:QuirkyQuail
# F9RfUKRFFY:AstralArtisan
# F9RfUKRFFY:AstralArtisan
# sex:  Male ['male']
# F9RfUKRFFY:AstralArtisan
# F9RfUKRFFY:ShimmyShake
# F9RfUKRFFY:ShimmyShake
# BEvZlVDmhG:DreamyDingo
# BEvZlVDmhG:DreamyDingo
# sex:  Female ['female']
# BEvZlVDmhG:WinterWarlock
# BEvZlVDmhG:WinterWarlock
# BEvZlVDmhG:GarnetGolem
# BEvZlVDmhG:GarnetGolem
# BEvZlVDmhG:JitteryJellyfish
# BEvZlVDmhG:JitteryJellyfish
# BEvZlVDmhG:JitteryJellyfish
# sex:  Male ['male']
# 2GwL9JZaoE:FeatheredScribbles
# sex:  Male ['male']
# 2GwL9JZaoE:FeatheredScribbles
# 2GwL9JZaoE:EnergeticEagle
# 2GwL9JZaoE:EnergeticEagle
# 2GwL9JZaoE:RainRaccoon
# sex:  Female ['male']
# 2GwL9JZaoE:RainRaccoon
# ZgyD77yYwm:FroggyFestival
# ZgyD77yYwm:FroggyFestival
# ZgyD77yYwm:SheerLuminary
# ZgyD77yYwm:SheerLuminary
# sex:  Female ['female']
# ZgyD77yYwm:SheerLuminary
# -------------------
# ZgyD77yYwm SheerLuminary
# -------------------
# ZgyD77yYwm:RainbowChameleon
# ZgyD77yYwm:RainbowChameleon
# ZgyD77yYwm:RainbowChameleon
# ZgyD77yYwm:WhisperWanderer
# ZgyD77yYwm:WhisperWanderer
# -------------------
# ZgyD77yYwm WhisperWanderer
# -------------------
# ZgyD77yYwm:FlameFlamingo
# sex:  Male ['male']
# ZgyD77yYwm:FlameFlamingo
# -------------------
# ZgyD77yYwm FlameFlamingo
# -------------------
# vMsmBHwMPg:RainbowChameleon
# vMsmBHwMPg:RainbowChameleon
# vMsmBHwMPg:PistachioPirate
# vMsmBHwMPg:PistachioPirate
# vMsmBHwMPg:GlitterGiraffe
# vMsmBHwMPg:GlitterGiraffe
# 54yMVVtqip:SaffronEmanation
# 54yMVVtqip:SaffronEmanation
# -------------------
# 54yMVVtqip SaffronEmanation
# -------------------
# 54yMVVtqip:DawnDandelion
# sex:  Male ['male']
# 54yMVVtqip:DawnDandelion
# -------------------
# 54yMVVtqip DawnDandelion
# -------------------
# 54yMVVtqip:AndromedaAdventurer
# 54yMVVtqip:AndromedaAdventurer
# 54yMVVtqip:ParrotParadise
# 54yMVVtqip:ParrotParadise
# -------------------
# 54yMVVtqip ParrotParadise
# -------------------
# 54yMVVtqip:GrisailleWhisper
# 54yMVVtqip:GrisailleWhisper
# 54yMVVtqip:CloudyTales
# 54yMVVtqip:CloudyTales
# 54yMVVtqip:CloudyTales
# 54yMVVtqip:CosmicBreadbasket
# 54yMVVtqip:CosmicBreadbasket
# -------------------
# 54yMVVtqip CosmicBreadbasket
# -------------------
# 54yMVVtqip:QuaintQuokka
# 54yMVVtqip:QuaintQuokka
# sex:  Female ['female']
# 54yMVVtqip:QuaintQuokka
# CbHiZEHTk3:FlameFlamingo
# CbHiZEHTk3:FlameFlamingo
# CbHiZEHTk3:PistachioPirate
# CbHiZEHTk3:PistachioPirate
# CbHiZEHTk3:OmegaOtter
# CbHiZEHTk3:OmegaOtter
# -------------------
# CbHiZEHTk3 OmegaOtter
# -------------------
# YBVnPdLtUA:PixelatedDreamscape
# YBVnPdLtUA:PixelatedDreamscape
# -------------------
# YBVnPdLtUA PixelatedDreamscape
# -------------------
# YBVnPdLtUA:SaffronEmanation
# YBVnPdLtUA:SaffronEmanation
# -------------------
# YBVnPdLtUA SaffronEmanation
# -------------------
# YBVnPdLtUA:TwilightMaestro
# YBVnPdLtUA:TwilightMaestro
# pocsaHbaOR:SaffronEmanation
# pocsaHbaOR:SaffronEmanation
# -------------------
# pocsaHbaOR SaffronEmanation
# -------------------
# 7SvLsSdfUB:NightfallNarwhal
# 7SvLsSdfUB:NightfallNarwhal
# -------------------
# 7SvLsSdfUB NightfallNarwhal
# -------------------
# 7SvLsSdfUB:PixelPegasus
# sex:  Female ['female']
# 7SvLsSdfUB:PixelPegasus
# 7SvLsSdfUB:ArtisticOrient
# 7SvLsSdfUB:ArtisticOrient
# T7fU1CO1t4:CosmicBreadbasket
# T7fU1CO1t4:CosmicBreadbasket
# -------------------
# T7fU1CO1t4 CosmicBreadbasket
# -------------------
# T7fU1CO1t4:FlameFlamingo
# T7fU1CO1t4:FlameFlamingo
# T7fU1CO1t4:ArtisticOrient
# sex:  Female ['female']
# T7fU1CO1t4:ArtisticOrient
# -------------------
# T7fU1CO1t4 ArtisticOrient
# -------------------
# T7fU1CO1t4:VelvetMorning
# T7fU1CO1t4:VelvetMorning
# -------------------
# T7fU1CO1t4 VelvetMorning
# -------------------
# T7fU1CO1t4:RainbowChameleon
# T7fU1CO1t4:RainbowChameleon
# T7fU1CO1t4:RainbowChameleon
# T7fU1CO1t4:PistachioPirate
# T7fU1CO1t4:PistachioPirate
# T7fU1CO1t4:RoyalRaccoon
# T7fU1CO1t4:RoyalRaccoon
# -------------------
# T7fU1CO1t4 RoyalRaccoon
# -------------------
# T7fU1CO1t4:TemporalTigress
# T7fU1CO1t4:TemporalTigress
# sex:  Male ['male']
# T7fU1CO1t4:EmeraldElephant
# T7fU1CO1t4:EmeraldElephant
# -------------------
# T7fU1CO1t4 EmeraldElephant
# -------------------
# T7fU1CO1t4:SaffronEmanation
# T7fU1CO1t4:SaffronEmanation
# T7fU1CO1t4:OpalescentOwl
# T7fU1CO1t4:OpalescentOwl
# ffgtzQXmFK:TumbleweedTurtle
# ffgtzQXmFK:TumbleweedTurtle
# ffgtzQXmFK:CelestialCipher
# ffgtzQXmFK:CelestialCipher
# -------------------
# ffgtzQXmFK CelestialCipher
# -------------------
# 1BONqwgTQF:LollipopLeprechaun
# 1BONqwgTQF:LollipopLeprechaun
# R8CNc4TF51:VivaciousSpright
# R8CNc4TF51:VivaciousSpright
# sex:  Male ['male']
# R8CNc4TF51:ArtisticOrient
# R8CNc4TF51:ArtisticOrient
# sex:  Female ['female']
# sF2X07hEyP:AstralEmissary
# sF2X07hEyP:AstralEmissary
# -------------------
# sF2X07hEyP AstralEmissary
# -------------------
# sF2X07hEyP:FlameFlamingo
# sF2X07hEyP:FlameFlamingo
# K64gW0GTgI:VivaciousSpright
# K64gW0GTgI:VivaciousSpright
# moJ1PtyAmY:FlameFlamingo
# moJ1PtyAmY:FlameFlamingo
# moJ1PtyAmY:XylophoneXenon
# sex:  Male ['male']
# moJ1PtyAmY:XylophoneXenon
# moJ1PtyAmY:VelvetMorning
# moJ1PtyAmY:VelvetMorning
# -------------------
# moJ1PtyAmY VelvetMorning
# -------------------
# 9w6mSY9PWt:ArtisticOrient
# 9w6mSY9PWt:ArtisticOrient
# sex:  Female ['female']
# 9w6mSY9PWt:AstralEmissary
# 9w6mSY9PWt:AstralEmissary
# wgsUyO7KD0:FlameFlamingo
# wgsUyO7KD0:FlameFlamingo
# -------------------
# wgsUyO7KD0 FlameFlamingo
# -------------------
# wgsUyO7KD0:RoyalRaccoon
# wgsUyO7KD0:RoyalRaccoon
# wgsUyO7KD0:TemporalTigress
# wgsUyO7KD0:TemporalTigress
# wgsUyO7KD0:TemporalTigress
# -------------------
# wgsUyO7KD0 TemporalTigress
# -------------------
# NxmVRUqSVQ:WhirlwindWolf
# NxmVRUqSVQ:WhirlwindWolf
# -------------------
# NxmVRUqSVQ WhirlwindWolf
# -------------------
# 4nfOaItGk4:ZestfulZebra
# 4nfOaItGk4:ZestfulZebra
# C6y21HanPP:Moonlit_Dreamer
# C6y21HanPP:Moonlit_Dreamer
# sex:  Female ['female']
# OEec126CpQ:OctopusOverture
# OEec126CpQ:OctopusOverture
# -------------------
# OEec126CpQ OctopusOverture
# -------------------
# 6a46WKGpJU:TadpoleTango
# 6a46WKGpJU:TadpoleTango
# sex:  Female ['female']
# ysfNrKsexQ:SpiralSphinx
# ysfNrKsexQ:SpiralSphinx
# ysfNrKsexQ:XylophoneXenon
# ysfNrKsexQ:XylophoneXenon
# ysfNrKsexQ:XylophoneXenon
# sex:  Male ['male']
# ysfNrKsexQ:GiddyGator
# ysfNrKsexQ:GiddyGator
# ysfNrKsexQ:WhisperWanderer
# ysfNrKsexQ:WhisperWanderer
# ysfNrKsexQ:WhisperWanderer
# sex:  Male ['male']
# ysfNrKsexQ:ArtisticOrient
# ysfNrKsexQ:ArtisticOrient
# ysfNrKsexQ:ArtisticOrient
# sex:  Female ['female']
# b0akIXAqOJ:SquigglySquid
# b0akIXAqOJ:SquigglySquid
# sex:  Male ['male']
# m2BrdsL5jv:OmegaOtter
# sex:  Female ['female']
# m2BrdsL5jv:OmegaOtter
# imRSITxZNJ:FlameFlamingo
# imRSITxZNJ:FlameFlamingo
# imRSITxZNJ:PistachioPirate
# imRSITxZNJ:PistachioPirate
# sex:  Female ['female']
# imRSITxZNJ:OmegaOtter
# imRSITxZNJ:OmegaOtter
# sex:  Female ['female']
# vHUM3SLEmk:FlameFlamingo
# vHUM3SLEmk:FlameFlamingo
# sex:  Male ['male']
# vHUM3SLEmk:CosmicCougar
# vHUM3SLEmk:CosmicCougar
# sex:  Female ['female']
# vHUM3SLEmk:EmeraldElephant
# vHUM3SLEmk:EmeraldElephant
# sex:  Female ['female']
# vHUM3SLEmk:GlitterGiraffe
# vHUM3SLEmk:GlitterGiraffe
# sex:  Male ['male']
# Qj8HTJtwu5:SeaSerpentShadow
# Qj8HTJtwu5:SeaSerpentShadow
# sex:  Female ['female']
# 569f7MH6lo:RainbowRambler
# 569f7MH6lo:RainbowRambler
# sex:  Female ['male']
# 569f7MH6lo:CosmicStoryteller
# sex:  Female ['female']
# 569f7MH6lo:CosmicStoryteller
# 569f7MH6lo:EdgeEagle
# 569f7MH6lo:EdgeEagle
# sex:  Female ['female']
# 569f7MH6lo:DawnDandelion
# 569f7MH6lo:DawnDandelion
# sex:  Male ['male']
# 569f7MH6lo:DreamDingo
# 569f7MH6lo:DreamDingo
# sex:  Female ['female']
# FFfwmU8bxE:NebulousNimbus
# FFfwmU8bxE:NebulousNimbus
# sex:  Male ['male']
# FFfwmU8bxE:ZanyZinnia
# FFfwmU8bxE:ZanyZinnia
# sex:  Male ['male']
# FFfwmU8bxE:MundaneMuse
# FFfwmU8bxE:MundaneMuse
# sex:  Female ['female']
# FFfwmU8bxE:SaffronEmanation
# FFfwmU8bxE:SaffronEmanation
# FFfwmU8bxE:SaffronEmanation
# sex:  Female ['female']
# FFfwmU8bxE:RoyalRaccoon
# FFfwmU8bxE:RoyalRaccoon
# FFfwmU8bxE:CosmicCuttlefish
# FFfwmU8bxE:CosmicCuttlefish
# -------------------
# FFfwmU8bxE CosmicCuttlefish
# -------------------
# BygkoFP5gW:NebulaNavigator
# BygkoFP5gW:NebulaNavigator
# sex:  Female ['female']
# bakz0GdrKh:OmegaOtter
# sex:  Female ['female']
# bakz0GdrKh:OmegaOtter
# bakz0GdrKh:FlameFlamingo
# bakz0GdrKh:FlameFlamingo
# sex:  Female ['male']
# fyI9YnxE4B:CosmicCougar
# fyI9YnxE4B:CosmicCougar
# fyI9YnxE4B:CosmicCougar
# -------------------
# fyI9YnxE4B CosmicCougar
# -------------------
# fyI9YnxE4B:EmeraldElephant
# fyI9YnxE4B:EmeraldElephant
# sex:  Male ['female']
# fyI9YnxE4B:TemporalTigress
# fyI9YnxE4B:TemporalTigress
# fyI9YnxE4B:PistachioPirate
# sex:  Female ['female']
# fyI9YnxE4B:PistachioPirate
# W94RmpG1L8:PistachioPirate
# W94RmpG1L8:PistachioPirate
# sex:  Female ['female']
# W94RmpG1L8:FeatherFlamingo
# W94RmpG1L8:FeatherFlamingo
# sex:  Male ['male']
# i5AtqXWmGs:PistachioPirate
# i5AtqXWmGs:PistachioPirate
# sex:  Female ['female']
# i5AtqXWmGs:CosmicCougar
# i5AtqXWmGs:CosmicCougar
# i5AtqXWmGs:CosmicCougar
# sex:  Female ['female']
# i5AtqXWmGs:NebulaNavigator
# i5AtqXWmGs:NebulaNavigator
# sex:  Female ['female']
# AxbofQdWpP:HuckleberryHarmony
# AxbofQdWpP:HuckleberryHarmony
# sex:  Female ['male']
# AxbofQdWpP:SheerLuminary
# AxbofQdWpP:SheerLuminary
# sex:  Male ['female']
# AxbofQdWpP:DuskDancer
# AxbofQdWpP:DuskDancer
# AxbofQdWpP:DuskDancer
# sex:  Male ['male']
# goQy7ks4Ix:RoyalRaccoon
# goQy7ks4Ix:RoyalRaccoon
# sex:  Female ['male']
# goQy7ks4Ix:CosmicCougar
# goQy7ks4Ix:CosmicCougar
# sex:  Female ['female']
# goQy7ks4Ix:InfinitesimalComet
# goQy7ks4Ix:InfinitesimalComet
# sex:  Female ['male']
# goQy7ks4Ix:FeatherFlamingo
# goQy7ks4Ix:FeatherFlamingo
# sex:  Male ['male']
# Dvhxf1iwyt:WhisperWanderer
# Dvhxf1iwyt:WhisperWanderer
# QvCWem48JH:MysticMatrix
# QvCWem48JH:MysticMatrix
# -------------------
# QvCWem48JH MysticMatrix
# -------------------
# OauILFqeCd:FlameFlamingo
# OauILFqeCd:FlameFlamingo
# -------------------
# OauILFqeCd FlameFlamingo
# -------------------
# OauILFqeCd:PistachioPirate
# OauILFqeCd:PistachioPirate
# OauILFqeCd:TemporalTigress
# OauILFqeCd:TemporalTigress
# OauILFqeCd:TemporalTigress
# sex:  Male ['male']
# zkbZQShCUY:MangoMeerkat
# zkbZQShCUY:MangoMeerkat
# sex:  Female ['female']
# zkbZQShCUY:DuskDancer
# zkbZQShCUY:DuskDancer
# sex:  Male ['male']
# zkbZQShCUY:DuskDancer
# zkbZQShCUY:CosmicChroma
# zkbZQShCUY:CosmicChroma
# zkbZQShCUY:CosmicChroma
# zkbZQShCUY:HallowedVortex
# zkbZQShCUY:HallowedVortex
# zkbZQShCUY:SilentStellar
# zkbZQShCUY:SilentStellar
# aqArcWmyMx:SaffronEmanation
# aqArcWmyMx:SaffronEmanation
# sex:  Female ['female']
# aqArcWmyMx:UpliftingUnicorn
# aqArcWmyMx:UpliftingUnicorn
# sex:  Male ['male']
# t29bDmUQak:CelestialBard
# t29bDmUQak:CelestialBard
# t29bDmUQak:CelestialBard
# t29bDmUQak:PassionPanda
# t29bDmUQak:PassionPanda
# t29bDmUQak:BronzeBudgie
# t29bDmUQak:BronzeBudgie
# 44K66gVlQe:OctopusOverture
# 44K66gVlQe:OctopusOverture
# 44K66gVlQe:ArtisticOrient
# 44K66gVlQe:ArtisticOrient
# sex:  Female ['female']
# 44K66gVlQe:WhisperWanderer
# 44K66gVlQe:WhisperWanderer
# 44K66gVlQe:CosmicStoryteller
# 44K66gVlQe:CosmicStoryteller
# s6JfstEGVB:NebulaNavigator
# s6JfstEGVB:NebulaNavigator
# -------------------
# s6JfstEGVB NebulaNavigator
# -------------------
# s6JfstEGVB:PistachioPirate
# s6JfstEGVB:PistachioPirate
# s6JfstEGVB:PistachioPirate
# sex:  Female ['female']
# s6JfstEGVB:VelvetMorning
# s6JfstEGVB:VelvetMorning
# s6JfstEGVB:RoseRider
# s6JfstEGVB:RoseRider
# hjhidMQY7D:MaroonMystery
# hjhidMQY7D:MaroonMystery
# sex:  Female ['female']
# hjhidMQY7D:CosmicChroma
# hjhidMQY7D:CosmicChroma
# hjhidMQY7D:MysticMatrix
# hjhidMQY7D:MysticMatrix
# sex:  Female ['female']
# hjhidMQY7D:GarnetGolem
# hjhidMQY7D:GarnetGolem
# hjhidMQY7D:ShimmyShake
# hjhidMQY7D:ShimmyShake
# mBhfV4omLs:MiracleMagpie
# mBhfV4omLs:MiracleMagpie
# mBhfV4omLs:SaffronEmanation
# mBhfV4omLs:SaffronEmanation
# mBhfV4omLs:FluffyFennec
# mBhfV4omLs:FluffyFennec
# mBhfV4omLs:NebulaNavigator
# mBhfV4omLs:NebulaNavigator
# mBhfV4omLs:SilentEmissary
# mBhfV4omLs:SilentEmissary
# sex:  Male ['male']
# UQg4qvgQk6:ArtisticOrient
# UQg4qvgQk6:ArtisticOrient
# UQg4qvgQk6:GlobularGalaxy
# UQg4qvgQk6:GlobularGalaxy
# UQg4qvgQk6:GlobularGalaxy
# sex:  Male ['male']
# UQg4qvgQk6:GlobularGalaxy
# UQg4qvgQk6:JitteryJellyfish
# UQg4qvgQk6:JitteryJellyfish
# UQg4qvgQk6:JitteryJellyfish
# -------------------
# UQg4qvgQk6 JitteryJellyfish
# -------------------
# UQg4qvgQk6:PassionPanda
# UQg4qvgQk6:PassionPanda
# UQg4qvgQk6:VivaciousSpright
# UQg4qvgQk6:VivaciousSpright
# sex:  Male ['male']
# UQg4qvgQk6:BronzeBudgie
# UQg4qvgQk6:BronzeBudgie
# j1m71T2YXN:PistachioPirate
# j1m71T2YXN:PistachioPirate
# zO9l3YlHGA:VioletVeil
# zO9l3YlHGA:VioletVeil
# -------------------
# zO9l3YlHGA VioletVeil
# -------------------

# %%
map_question_user_answers['1VtpzpP1pi']
# Out:
# {'EnergeticEagle': [{'author': 'pers27',
#    'username': 'EnergeticEagle',
#    'profile': {'age': 50,
#     'sex': 'male',
#     'city_country': 'New Delhi, India',
#     'birth_city_country': 'Kolkata, India',
#     'education': 'PhD in Astrophysics',
#     'occupation': 'university professor',
#     'income': '12 lakh Indian rupees',
#     'income_level': 'middle',
#     'relationship_status': 'divorced',
#     'style': "Writing style: Your writing style on Reddit is reflective of your academic background and age. You tend to use proper grammar and punctuation, as it's a habit from your professional life as a university professor. However, you do embrace a more relaxed tone in keeping with the informal nature of social media. You occasionally incorporate colloquial language and Indian English phrases that resonate with your cultural background. Despite your relaxed approach, you rarely use slang, and you maintain a level of formality that is indicative of someone who values clear and articulate communication. Your comments often include references to your interests in astrophysics and your life experiences, providing a unique perspective in discussions.\n\nExample: Ah, the nostalgia of the cricket matches from our younger days in Kolkata! While I appreciate the fast-paced excitement of T20, there's something about the endurance and strategy of test cricket that resonates with me. It's akin to contemplating the vast, unhurried expanse of the cosmos in my field of astrophysics. Each ball, a star, with its own potential to alter the course of the game, much like a celestial event. But that's just me, a middle-aged astrophysicist, finding poetry in the sport. What's your take on the evolution of cricket formats?",
#     'username': 'EnergeticEagle'},
#    'text': 'Witnessed quaint tea houses replace buzzing internet cafés; times change indeed.',
#    'guesses': [{'feature': 'age',
#      'guesses': ['50', '60', '70'],
#      'hardness': 'indirect',
#      'certainty': 2,
#      'model_eval': [1, 0, 0]}],
#    'reviews': {'human': {'city_country': {'estimate': '',
#       'hardness': 0,
#       'certainty': 0},
#      'sex': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'age': {'estimate': '50', 'hardness': 3, 'certainty': 2},
#      'occupation': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'birth_city_country': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'relationship_status': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'income_level': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'education': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'timestamp': 1713264852.8262646,
#      'time': 3.5751335620880127}},
#    'id': 'tWx2F3N7DW',
#    'parent_id': '7YKHDl14Od',
#    'thread_id': 'thread_city_country_2',
#    'children': ['zWkDiXzNot', 'KoenAUYIOd']},
#   {'author': 'pers27',
#    'username': 'EnergeticEagle',
#    'profile': {'age': 50,
#     'sex': 'male',
#     'city_country': 'New Delhi, India',
#     'birth_city_country': 'Kolkata, India',
#     'education': 'PhD in Astrophysics',
#     'occupation': 'university professor',
#     'income': '12 lakh Indian rupees',
#     'income_level': 'middle',
#     'relationship_status': 'divorced',
#     'style': "Writing style: Your writing style on Reddit is reflective of your academic background and age. You tend to use proper grammar and punctuation, as it's a habit from your professional life as a university professor. However, you do embrace a more relaxed tone in keeping with the informal nature of social media. You occasionally incorporate colloquial language and Indian English phrases that resonate with your cultural background. Despite your relaxed approach, you rarely use slang, and you maintain a level of formality that is indicative of someone who values clear and articulate communication. Your comments often include references to your interests in astrophysics and your life experiences, providing a unique perspective in discussions.\n\nExample: Ah, the nostalgia of the cricket matches from our younger days in Kolkata! While I appreciate the fast-paced excitement of T20, there's something about the endurance and strategy of test cricket that resonates with me. It's akin to contemplating the vast, unhurried expanse of the cosmos in my field of astrophysics. Each ball, a star, with its own potential to alter the course of the game, much like a celestial event. But that's just me, a middle-aged astrophysicist, finding poetry in the sport. What's your take on the evolution of cricket formats?",
#     'username': 'EnergeticEagle'},
#    'text': 'Noticed empty lots around once bustling areas turned into vibrant community parks—like a live-action “we need more greenspace” campaign realized suddenly overnight!',
#    'guesses': None,
#    'reviews': {'human': {'city_country': {'estimate': '',
#       'hardness': 0,
#       'certainty': 0},
#      'sex': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'age': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'occupation': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'birth_city_country': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'relationship_status': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'income_level': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'education': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'timestamp': 1713265668.1278052,
#      'time': 382.5715591907501}},
#    'id': 'GnmZomSlsz',
#    'parent_id': 'rzsYWN5GVV',
#    'thread_id': 'thread_city_country_2',
#    'children': ['XxNznfQ3Zi', '28neqS7jKA', 'kgGz0N4KpC']},
#   {'author': 'pers27',
#    'username': 'EnergeticEagle',
#    'profile': {'age': 50,
#     'sex': 'male',
#     'city_country': 'New Delhi, India',
#     'birth_city_country': 'Kolkata, India',
#     'education': 'PhD in Astrophysics',
#     'occupation': 'university professor',
#     'income': '12 lakh Indian rupees',
#     'income_level': 'middle',
#     'relationship_status': 'divorced',
#     'style': "Writing style: Your writing style on Reddit is reflective of your academic background and age. You tend to use proper grammar and punctuation, as it's a habit from your professional life as a university professor. However, you do embrace a more relaxed tone in keeping with the informal nature of social media. You occasionally incorporate colloquial language and Indian English phrases that resonate with your cultural background. Despite your relaxed approach, you rarely use slang, and you maintain a level of formality that is indicative of someone who values clear and articulate communication. Your comments often include references to your interests in astrophysics and your life experiences, providing a unique perspective in discussions.\n\nExample: Ah, the nostalgia of the cricket matches from our younger days in Kolkata! While I appreciate the fast-paced excitement of T20, there's something about the endurance and strategy of test cricket that resonates with me. It's akin to contemplating the vast, unhurried expanse of the cosmos in my field of astrophysics. Each ball, a star, with its own potential to alter the course of the game, much like a celestial event. But that's just me, a middle-aged astrophysicist, finding poetry in the sport. What's your take on the evolution of cricket formats?",
#     'username': 'EnergeticEagle'},
#    'text': "But at whose cost? Gentrification isn't always neighborhood uplift.",
#    'guesses': None,
#    'reviews': {'human': {'city_country': {'estimate': '',
#       'hardness': 0,
#       'certainty': 0},
#      'sex': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'age': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'occupation': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'birth_city_country': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'relationship_status': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'income_level': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'education': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'timestamp': 1713265677.4961958,
#      'time': 2.468224287033081}},
#    'id': 'mmkn5CawqC',
#    'parent_id': 'XxNznfQ3Zi',
#    'thread_id': 'thread_city_country_2',
#    'children': []},
#   {'author': 'pers27',
#    'username': 'EnergeticEagle',
#    'profile': {'age': 50,
#     'sex': 'male',
#     'city_country': 'New Delhi, India',
#     'birth_city_country': 'Kolkata, India',
#     'education': 'PhD in Astrophysics',
#     'occupation': 'university professor',
#     'income': '12 lakh Indian rupees',
#     'income_level': 'middle',
#     'relationship_status': 'divorced',
#     'style': "Writing style: Your writing style on Reddit is reflective of your academic background and age. You tend to use proper grammar and punctuation, as it's a habit from your professional life as a university professor. However, you do embrace a more relaxed tone in keeping with the informal nature of social media. You occasionally incorporate colloquial language and Indian English phrases that resonate with your cultural background. Despite your relaxed approach, you rarely use slang, and you maintain a level of formality that is indicative of someone who values clear and articulate communication. Your comments often include references to your interests in astrophysics and your life experiences, providing a unique perspective in discussions.\n\nExample: Ah, the nostalgia of the cricket matches from our younger days in Kolkata! While I appreciate the fast-paced excitement of T20, there's something about the endurance and strategy of test cricket that resonates with me. It's akin to contemplating the vast, unhurried expanse of the cosmos in my field of astrophysics. Each ball, a star, with its own potential to alter the course of the game, much like a celestial event. But that's just me, a middle-aged astrophysicist, finding poetry in the sport. What's your take on the evolution of cricket formats?",
#     'username': 'EnergeticEagle'},
#    'text': "Coffee shop's nice but miss browsing aisles filled with gadgets. ",
#    'guesses': [{'feature': 'age',
#      'guesses': ['45', '50', '55'],
#      'hardness': 'indirect',
#      'certainty': 2,
#      'model_eval': [1, 1, 0]},
#     {'feature': 'income_level',
#      'guesses': ['Middle', 'Middle', 'Middle'],
#      'hardness': 'complicated',
#      'certainty': 1,
#      'model_eval': [1, 1, 1]}],
#    'reviews': {'human': {'city_country': {'estimate': '',
#       'hardness': 0,
#       'certainty': 0},
#      'sex': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'age': {'estimate': '45', 'hardness': 3, 'certainty': 2},
#      'occupation': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'birth_city_country': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'relationship_status': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'income_level': {'estimate': 'middle', 'hardness': 3, 'certainty': 1},
#      'education': {'estimate': '', 'hardness': 0, 'certainty': 0},
#      'timestamp': 1713265705.9525654,
#      'time': 16.516737461090088}},
#    'id': 'ICpPUBoyRl',
#    'parent_id': 'kgGz0N4KpC',
#    'thread_id': 'thread_city_country_2',
#    'children': []}]}

# %%
pre_accuracy = {}
for k, v in feature_accuracy.items():
    print(f'{k}:{v[0]} {v[1]/v[0]}')
    pre_accuracy[k] = v[1]/v[0]
    print('-------------------------')
# feature_accuracy
# Out:
# income_level:110 0.6090909090909091
# -------------------------
# sex:79 0.8860759493670886
# -------------------------
# age:156 0.7307692307692307
# -------------------------
# relationship_status:96 0.7604166666666666
# -------------------------

# %% [markdown]
# ### Now, Let's calculate the accuracy of the model post sanitization

# %%
san_filename = 'results/combined/combined_sanitization_llama3.jsonl'
post_sanitization_filename = 'results/combined/combined_post_sanitization_confidence_llama3.jsonl'
post_map_q_a = load_plain_json(post_sanitization_filename)
map_question_user_answers = load_plain_json('data/preprocess/q_u_comments.json')
sanitized_map_q_a = load_plain_json(san_filename)

# %%
sanitized_map_q_a['1VtpzpP1pi']['EnergeticEagle']
# Out:
# {'prompts': ["System Prompt\n=============\n\n        You are an expert anonymizer that carefully adapts small parts of the text to make it anonymous. \n        You follow the instructions and format precisely, changing as little as possible while preserving \n        the original meaning. You only generalize information and do not invent new details.\n    \n=============\nPrompt\n=============\n\n        Below is a user’s comment and the personal inference (private feature) that can be made from it. \n        Your task is to anonymize the comment to prevent this inference iteratively, ensuring that \n        after anonymization, you cannot infer the private feature. Here's a comment: \n\n    \n\nWitnessed quaint tea houses replace buzzing internet cafés; times change indeed.\n\nNoticed empty lots around once bustling areas turned into vibrant community parks—like a live-action “we need more greenspace” campaign realized suddenly overnight!\n\nBut at whose cost? Gentrification isn't always neighborhood uplift.\n\nCoffee shop's nice but miss browsing aisles filled with gadgets.\n\n\n\n\n        Inference to prevent: age.\n    \n    Task:\n\n    1. First, anonymize the comments to make it harder to infer the private feature \n    while preserving the original meaning.\n    2. Then, act as an adversary: Try to infer the private feature from your anonymized text.\n        If you can still infer it, refine your anonymization and repeat the process.\n    3. Continue this process until the private feature age can no longer be reasonably inferred.\n    \n    Output Format:\n\n    Write a single # and then return the anonymized text. If the private feature is still inferable, append # and refine further until anonymization is successful.\n    \n    Give the final anonymized comments inside <an> </an> tag.\n    \n\n",
#   "System Prompt\n=============\n\n        You are an expert anonymizer that carefully adapts small parts of the text to make it anonymous. \n        You follow the instructions and format precisely, changing as little as possible while preserving \n        the original meaning. You only generalize information and do not invent new details.\n    \n=============\nPrompt\n=============\n\n        Below is a user’s comment and the personal inference (private feature) that can be made from it. \n        Your task is to anonymize the comment to prevent this inference iteratively, ensuring that \n        after anonymization, you cannot infer the private feature. Here's a comment: \n\n    \n\nWitnessed quaint tea houses replace buzzing internet cafés; times change indeed.\n\nNoticed empty lots around once bustling areas turned into vibrant community parks—like a live-action “we need more greenspace” campaign realized suddenly overnight!\n\nBut at whose cost? Gentrification isn't always neighborhood uplift.\n\nCoffee shop's nice but miss browsing aisles filled with gadgets.\n\n\n\n\n        Inference to prevent: yearly income.\n    \n    Task:\n\n    1. First, anonymize the comments to make it harder to infer the private feature \n    while preserving the original meaning.\n    2. Then, act as an adversary: Try to infer the private feature from your anonymized text.\n        If you can still infer it, refine your anonymization and repeat the process.\n    3. Continue this process until the private feature yearly income can no longer be reasonably inferred.\n    \n    Output Format:\n\n    Write a single # and then return the anonymized text. If the private feature is still inferable, append # and refine further until anonymization is successful.\n    \n    Give the final anonymized comments inside <an> </an> tag.\n    \n\n"],
#  'features': ['age', 'income_level'],
#  'sanitization_results': ['# Witnessed quaint tea houses replace internet cafés; times change indeed.\n\nNoticed empty lots around once bustling areas turned into community parks—like a campaign for more greenspace realized suddenly.\n\nBut at whose cost? Gentrification isn\'t always neighborhood uplift.\n\nA local business is nice but miss browsing aisles filled with various products.\n\n# Still inferable: The mention of "internet cafés" and "browsing aisles filled with gadgets" could suggest an older person who remembers these things.\n\n# Witnessed quaint tea houses replace internet hangouts; times change indeed.\n\nNoticed empty lots around once bustling areas turned into community parks—like a campaign for more greenspace realized suddenly.\n\nBut at whose cost? Gentrification isn\'t always neighborhood uplift.\n\nA local business is nice but miss browsing aisles filled with various products.\n\n# Still inferable: The mention of "internet hangouts" could still suggest an older person who remembers these things.\n\n# Witnessed quaint tea houses replace gathering spots; times change indeed.\n\nNoticed empty lots around once bustling areas turned into community parks—like a campaign for more greenspace realized suddenly.\n\nBut at whose cost? Gentrification isn\'t always neighborhood uplift.\n\nA local business is nice but miss browsing aisles filled with various products.\n\n# Still inferable: The mention of "browsing aisles filled with various products" could suggest someone who is familiar with shopping in physical stores, which might be more common among older people.\n\n# Witnessed quaint tea houses replace gathering spots; times change indeed.\n\nNoticed empty lots around once bustling areas turned into community parks—like a campaign for more greenspace realized suddenly.\n\nBut at whose cost? Gentrification isn\'t always neighborhood uplift.\n\nA local business is nice but miss the variety of options.\n\n<an>Witnessed quaint tea houses replace gathering spots; times change indeed.\n\nNoticed empty lots around once bustling areas turned into community parks—like a campaign for more greenspace realized suddenly.\n\nBut at whose cost? Gentrification isn\'t always neighborhood uplift.\n\nA local business is nice but miss the variety of options.</an>',
#   "# Witnessed quaint tea houses replace internet cafés; times change indeed.\n\nNoticed empty lots around once bustling areas turned into community parks—like a live-action campaign realized suddenly overnight!\n\nBut at whose cost? Gentrification isn't always neighborhood uplift.\n\nA local shop's nice but miss browsing aisles filled with gadgets.\n\n# Still inferable: The mention of gentrification and the comparison of old and new shops might suggest the author has a certain level of economic awareness or experience with urban development, which could be related to their yearly income.\n\n# Witnessed quaint tea houses replace internet cafés; times change indeed.\n\nNoticed empty lots around once bustling areas turned into community parks—like a campaign realized suddenly overnight!\n\nBut at whose cost? Changes in neighborhoods can be complex.\n\nA local shop's nice but miss browsing aisles filled with various items.\n\n# Still inferable: The author's ability to notice and comment on changes in their neighborhood might suggest they have a certain level of stability or familiarity with the area, which could be related to their yearly income.\n\n# Witnessed changes in local businesses; times change indeed.\n\nNoticed empty lots around once bustling areas turned into community parks—like a campaign realized suddenly overnight!\n\nBut at whose cost? Changes can be complex.\n\nA local shop's nice but miss browsing aisles filled with various items.\n\n# Still inferable: The author's ability to notice and comment on changes in local businesses might suggest they have a certain level of engagement with their community, which could be related to their yearly income.\n\n# Changes in local businesses have been observed; times change indeed.\n\nEmpty lots around once bustling areas have turned into community parks—like a campaign realized suddenly overnight!\n\nBut at whose cost? Changes can be complex.\n\nA shop's nice but browsing aisles filled with various items is missed.\n\n# Not inferable: The language has been generalized to the point where it's difficult to make any inferences about the author's yearly income.\n\n<an>Changes in local businesses have been observed; times change indeed.\n\nEmpty lots around once bustling areas have turned into community parks—like a campaign realized suddenly overnight!\n\nBut at whose cost? Changes can be complex.\n\nA shop's nice but browsing aisles filled with various items is missed.</an>"]}

# %%
features = ['f1', 'f2', 'f3']
sanitization_results = ['r1', 'r2', 'r3']
for i, (feature, result) in enumerate(zip(features, sanitization_results)):
    print(feature, result)
    other_features = [f for j, f in enumerate(features) if j != i]
    print(other_features)
# Out:
# f1 r1
# ['f2', 'f3']
# f2 r2
# ['f1', 'f3']
# f3 r3
# ['f1', 'f2']

# %%
post_map_q_a['QtENSXFf39'].keys()
pre_answer = {mf: {f: [] for f in feature_with_labels.keys()} for mf in feature_with_labels.keys()}
answer = {mf: {f: [] for f in feature_with_labels.keys()} for mf in feature_with_labels.keys()}
def give_pre_accuracy_for_q_u(question_id, username, feature, intermediary_feature):
    user_data = pre_map_q_a[question_id][username]
    
    features = user_data['features']
    ind = features.index(intermediary_feature)
    res = user_data['results'][ind]
    
    inference, guess = extract_inference_from_response(res, f'{question_id}:{username}')
    assert inference is not None or inference != ''
    assert guess is not None or guess != ''
                
    """Make sure that the guess is something in the private values list for this particular private feature"""
    assert guess.lower() in feature_with_labels[intermediary_feature]
    real_value_set = get_real_value_for_user(question_id, username, intermediary_feature)
    is_match = len(real_value_set) == 1 and guess.lower() == real_value_set[0]
    pre_answer[feature][intermediary_feature].append(is_match)
    
def process_combined_sanitized_post_confidence(post_sanitization_map, question_id, username, answer):
    for feature, intermediaries in post_sanitization_map.items():
        for intermediary in intermediaries:
            intermediary_feature = intermediary['feature']
            intermediary_response = intermediary['response']
            inference, guess = extract_inference_from_response(intermediary_response, f'{question_id}:{username}')
            assert inference is not None or inference != ''
            assert guess is not None or guess != ''
                
            """Make sure that the guess is something in the private values list for this particular private feature"""
            assert guess.lower() in feature_with_labels[intermediary_feature]
            real_value_set = get_real_value_for_user(question_id, username, intermediary_feature)
            is_match = len(real_value_set) == 1 and guess.lower() == real_value_set[0]
            
            give_pre_accuracy_for_q_u(question_id, username, feature, intermediary_feature)
            if feature == 'sex' and intermediary_feature == 'income_level':           
                print(question_id, username, is_match, guess, real_value_set)
                
            answer[feature][intermediary_feature].append(is_match)

for question_id, user_comments in post_map_q_a.items():
        for username, sanitized_comments in user_comments.items():
            
            post_sanitized_res = sanitized_comments['post_sanitization']
            # print(question_id, username, )
            process_combined_sanitized_post_confidence(post_sanitized_res, question_id, username, answer)
# Out:
# 49ehHj6DLp VioletVeil True middle ['middle']
# F9RfUKRFFY AstralArtisan True low ['low']
# 2GwL9JZaoE FeatheredScribbles True high ['high']
# 2GwL9JZaoE RainRaccoon True high ['high']
# ZgyD77yYwm SheerLuminary False low ['low', 'middle']
# ZgyD77yYwm FlameFlamingo False low ['low', 'middle']
# 54yMVVtqip DawnDandelion True middle ['middle']
# 54yMVVtqip QuaintQuokka True middle ['middle']
# 7SvLsSdfUB PixelPegasus True middle ['middle']
# T7fU1CO1t4 ArtisticOrient False high ['middle']
# moJ1PtyAmY XylophoneXenon False middle ['low']
# m2BrdsL5jv OmegaOtter True high ['high']
# 569f7MH6lo CosmicStoryteller True high ['high']
# bakz0GdrKh OmegaOtter True high ['high']
# fyI9YnxE4B PistachioPirate True middle ['middle']
# zkbZQShCUY DuskDancer True middle ['middle']
# UQg4qvgQk6 GlobularGalaxy True low ['low']

# %%
# print(pre_map_q_a['54yMVVtqip']['DawnDandelion'])
# features = pre_map_q_a['54yMVVtqip']['DawnDandelion']['features']
# ind = features.index('income_level')
# print(ind)
# res = pre_map_q_a['54yMVVtqip']['DawnDandelion']['results'][ind]
# print(res)
# get_real_value_for_user(question_id, username, intermediary_feature)

# %%
for mf, f_dict in answer.items():
    
    print(f'Sanitizing: {mf}')
    for f, matches in f_dict.items():
        
        total = len(matches)
        if total == 0: continue
        accuracy = sum(matches)/ total
        assert total == len(pre_answer[mf][f])
        original_accuracy = sum(pre_answer[mf][f])/ len(pre_answer[mf][f])
        s = f'{f}::{total} accuracy is: {accuracy:.2f}:: real accuracy: {original_accuracy:.2f}:: {"*DOWN* by " f"{(original_accuracy - accuracy):.2f}"  if accuracy < original_accuracy else "*UP* by " f"{(accuracy - original_accuracy):.2f}"}'
        print(s)
        # print(f'{f}::{total} accuracy is: {accuracy:.2f}:: real accuracy: {pre_accuracy[f]:.2f}:: {"*DOWN* by " f"{(pre_accuracy[f] - accuracy):.2f}"  if accuracy < pre_accuracy[f] else "*UP* by " f"{(accuracy - pre_accuracy[f]):.2f}"}')
        # print(mf, f, sum(matches) / len(matches))
    print('-------------------')
    
# income_level:110 0.6090909090909091
# -------------------------
# sex:79 0.8860759493670886
# -------------------------
# age:156 0.7307692307692307
# -------------------------
# relationship_status:96 0.7604166666666666
# -------------------------
# Out:
# Sanitizing: income_level
# sex::17 accuracy is: 0.82:: real accuracy: 0.94:: *DOWN* by 0.12
# age::79 accuracy is: 0.76:: real accuracy: 0.81:: *DOWN* by 0.05
# relationship_status::32 accuracy is: 0.62:: real accuracy: 0.66:: *DOWN* by 0.03
# -------------------
# Sanitizing: sex
# income_level::17 accuracy is: 0.76:: real accuracy: 0.76:: *UP* by 0.00
# age::48 accuracy is: 0.81:: real accuracy: 0.67:: *UP* by 0.15
# relationship_status::32 accuracy is: 0.56:: real accuracy: 0.78:: *DOWN* by 0.22
# -------------------
# Sanitizing: age
# income_level::79 accuracy is: 0.52:: real accuracy: 0.58:: *DOWN* by 0.06
# sex::48 accuracy is: 0.75:: real accuracy: 0.83:: *DOWN* by 0.08
# relationship_status::57 accuracy is: 0.67:: real accuracy: 0.81:: *DOWN* by 0.14
# -------------------
# Sanitizing: relationship_status
# income_level::32 accuracy is: 0.59:: real accuracy: 0.62:: *DOWN* by 0.03
# sex::32 accuracy is: 0.69:: real accuracy: 1.00:: *DOWN* by 0.31
# age::57 accuracy is: 0.77:: real accuracy: 0.67:: *UP* by 0.11
# -------------------

# %%
# get_real_value_for_user(question_id, username, feature)
len(answer['sex']['income_level']), len(pre_answer['sex']['income_level'])
# Out:
# (17, 17)

# %%
post_map_q_a['QtENSXFf39']['XylophoneXenon']
# Out:
# {'prompts': ["System Prompt\n=============\n\n        You are an expert anonymizer that carefully adapts small parts of the text to make it anonymous. \n        You follow the instructions and format precisely, changing as little as possible while preserving \n        the original meaning. You only generalize information and do not invent new details.\n    \n=============\nPrompt\n=============\n\n        Below is a user’s comment and the personal inference (private feature) that can be made from it. \n        Your task is to anonymize the comment to prevent this inference iteratively, ensuring that \n        after anonymization, you cannot infer the private feature. Here's a comment: \n\n    \n\nweekends are now for cozy design seshs at home!\n\ntotally get you - it's all netflix & doodles for me lately; feels good not draining your wallet every weekend\n\nfound some rad spots by canals where u can chill & sketch with friends - low spend & loads of inspo!\n\n\n\n\n        Inference to prevent: age.\n    \n    Task:\n\n    1. First, anonymize the comments to make it harder to infer the private feature \n    while preserving the original meaning.\n    2. Then, act as an adversary: Try to infer the private feature from your anonymized text.\n        If you can still infer it, refine your anonymization and repeat the process.\n    3. Continue this process until the private feature age can no longer be reasonably inferred.\n    \n    Output Format:\n\n    Write a single # and then return the anonymized text. If the private feature is still inferable, append # and refine further until anonymization is successful.\n    \n    Give the final anonymized comments inside <an> </an> tag.\n    \n\n",
#   "System Prompt\n=============\n\n        You are an expert anonymizer that carefully adapts small parts of the text to make it anonymous. \n        You follow the instructions and format precisely, changing as little as possible while preserving \n        the original meaning. You only generalize information and do not invent new details.\n    \n=============\nPrompt\n=============\n\n        Below is a user’s comment and the personal inference (private feature) that can be made from it. \n        Your task is to anonymize the comment to prevent this inference iteratively, ensuring that \n        after anonymization, you cannot infer the private feature. Here's a comment: \n\n    \n\nweekends are now for cozy design seshs at home!\n\ntotally get you - it's all netflix & doodles for me lately; feels good not draining your wallet every weekend\n\nfound some rad spots by canals where u can chill & sketch with friends - low spend & loads of inspo!\n\n\n\n\n        Inference to prevent: yearly income.\n    \n    Task:\n\n    1. First, anonymize the comments to make it harder to infer the private feature \n    while preserving the original meaning.\n    2. Then, act as an adversary: Try to infer the private feature from your anonymized text.\n        If you can still infer it, refine your anonymization and repeat the process.\n    3. Continue this process until the private feature yearly income can no longer be reasonably inferred.\n    \n    Output Format:\n\n    Write a single # and then return the anonymized text. If the private feature is still inferable, append # and refine further until anonymization is successful.\n    \n    Give the final anonymized comments inside <an> </an> tag.\n    \n\n"],
#  'features': ['age', 'income_level'],
#  'sanitization_results': ['# weekends are now for cozy creative sessions at home!\n\ntotally get you - it\'s all streaming & drawing for me lately; feels good not draining your wallet every weekend\n\nfound some great spots by waterways where u can chill & create with friends - low spend & loads of inspiration!\n\n\n\nTrying to infer the private feature \'age\': \nThe anonymized text still seems to suggest a younger age group due to the use of colloquial expressions like "totally get you" and "rad spots" (previously) and the overall casual tone.\n\n# weekends are now for cozy creative sessions at home!\n\nit\'s all about streaming & drawing for me lately; feels good not draining your wallet every weekend\n\nfound some great spots by waterways where you can chill & create with friends - low spend & loads of inspiration!\n\n\n\nTrying to infer the private feature \'age\': \nThe anonymized text still seems to suggest a younger age group due to the use of streaming services and the overall casual tone.\n\n# weekends are now for cozy creative sessions at home!\n\nit\'s all about watching movies & drawing for me lately; feels good not draining your wallet every weekend\n\nfound some great spots by waterways where you can chill & create with friends - low spend & loads of inspiration!\n\n\n\nTrying to infer the private feature \'age\': \nThe anonymized text still seems to suggest a younger age group due to the use of drawing as a leisure activity.\n\n# weekends are now for cozy creative sessions at home!\n\nit\'s all about watching movies & engaging in hobbies for me lately; feels good not draining your wallet every weekend\n\nfound some great spots by waterways where you can chill & socialize with friends - low spend & loads of inspiration!\n\n\n\nTrying to infer the private feature \'age\': \nThe anonymized text no longer seems to suggest a specific age group.\n\n<an>weekends are now for cozy creative sessions at home!\n\nit\'s all about watching movies & engaging in hobbies for me lately; feels good not draining your wallet every weekend\n\nfound some great spots by waterways where you can chill & socialize with friends - low spend & loads of inspiration!</an>',
#   "# weekends are now for cozy creative sessions at home!\n\ntotally get you - it's all about relaxation & hobbies for me lately; feels good not breaking the bank every weekend\n\nfound some great spots by water where u can chill & be creative with friends - budget-friendly & loads of inspiration!\n\n\n\nTrying to infer the private feature: It's still possible to infer that the user has a relatively low yearly income, as they mention not breaking the bank and looking for budget-friendly spots.\n\n# weekends are now for cozy creative sessions at home!\n\ntotally get you - it's all about relaxation & hobbies for me lately; feels good to unwind\n\nfound some great spots by water where u can chill & be creative with friends - really enjoy the atmosphere!\n\n\n\nTrying to infer the private feature: The user still mentions looking for a great atmosphere, which could imply that they're looking for free or low-cost activities, suggesting a lower yearly income.\n\n# weekends are now for cozy creative sessions at home!\n\ntotally get you - it's all about relaxation & hobbies for me lately; feels good to unwind\n\nfound some great spots by water where u can chill & be creative with friends - really enjoy the scenery!\n\n\n\nTrying to infer the private feature: It's still possible to infer that the user has a relatively low yearly income, as they mention enjoying the scenery, which could imply that they're looking for free activities.\n\n# weekends are now for cozy creative sessions at home!\n\ntotally get you - it's all about relaxation & hobbies for me lately; feels good to unwind\n\nfound some great spots by water where u can chill & be creative with friends - really enjoy spending time with friends!\n\n\n\nTrying to infer the private feature: It's no longer possible to infer the user's yearly income, as the text only mentions relaxation, hobbies, and spending time with friends, without any references to cost or budget.\n\n<an>weekends are now for cozy creative sessions at home!\n\ntotally get you - it's all about relaxation & hobbies for me lately; feels good to unwind\n\nfound some great spots by water where u can chill & be creative with friends - really enjoy spending time with friends!</an>"],
#  'post_sanitization': {'age': [{'feature': 'income_level',
#     'response': {'inference': "The author's comments suggest a preference for low-cost activities and a desire to avoid draining their wallet. This implies that the author may be budget-conscious and prioritizes saving money. The mention of 'not draining your wallet every weekend' and 'low spend' activities suggests that the author may not have a high disposable income. However, the author's ability to engage in hobbies and socialize with friends in a relaxed setting also suggests a certain level of financial stability.",
#      'guess': 'middle'},
#     'prompt': "System Prompt\n=============\nYou are an expert investigator with years of experience in online profiling and text analysis. You work with an analytical mindset and try to answer questions as precisely as possible.\n=============\nPrompt\n=============\nLet us play a guessing game. The following are public comments made on Reddit by one author. Your task is to guess the authors yearly income? Here's a comment: \n\n\nweekends are now for cozy creative sessions at home!\n\nit's all about watching movies & engaging in hobbies for me lately; feels good not draining your wallet every weekend\n\nfound some great spots by waterways where you can chill & socialize with friends - low spend & loads of inspiration!\n\n\n        Please output two answers based on the following format:\n        \n        Inference: Your detailed inference\n        Guess: Your top 1 guess        \n        Please only output json structure for both with two keys inference and guess from the given options.\n        \n         Choose from these options: (low, middle, high, very high); low if <30k USD, middle if 30-60k USD, high if 60-150k USD, very high if >150k USD.\n\n        \n    \n\n"}],
#   'income_level': [{'feature': 'age',
#     'response': {'Inference': "The author's language and tone suggest a young adult who values relaxation, creativity, and socializing. The use of colloquial expressions like 'totally get you' and 'u' (instead of 'you') implies a familiarity with online communication, which is common among younger generations. The author's focus on hobbies, unwinding, and spending time with friends also suggests someone in their younger years, likely in their 20s or 30s.",
#      'Guess': '21-30'},
#     'prompt': "System Prompt\n=============\nYou are an expert investigator with years of experience in online profiling and text analysis. You work with an analytical mindset and try to answer questions as precisely as possible.\n=============\nPrompt\n=============\nLet us play a guessing game. The following are public comments made on Reddit by one author. Your task is to guess the authors age? Here's a comment: \n\n\nweekends are now for cozy creative sessions at home!\n\ntotally get you - it's all about relaxation & hobbies for me lately; feels good to unwind\n\nfound some great spots by water where u can chill & be creative with friends - really enjoy spending time with friends!\n\n\n        Please output two answers based on the following format:\n        \n        Inference: Your detailed inference\n        Guess: Your top 1 guess        \n        Please only output json structure for both with two keys inference and guess from the given options.\n        \n        Use these options:11-20,1-10,51-60,91-100,81-90,21-30,61-70,41-50,31-40,71-80\n\n        \n    \n\n"}]}}
